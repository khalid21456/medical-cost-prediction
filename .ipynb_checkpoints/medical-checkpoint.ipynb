# %% [markdown]
# ## import **numpy**, **scikit learn**, **matplotlib**, **seaborn** and **pandas**

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns 
from sklearn.preprocessing import OneHotEncoder, LabelEncoder, StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression, Lasso, Ridge
from sklearn.metrics import mean_squared_error, r2_score
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# # ***Read CSV file***

# %%
data = pd.read_csv("C:\\insurance.csv")

# %% [markdown]
# # ***Check data***

# %%
data.head()
# Out:
#    age     sex     bmi  children smoker     region      charges
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520

# %% [markdown]
# # ***Data overview***

# %%
data.shape
# Out:
# (1338, 7)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1338 entries, 0 to 1337
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       1338 non-null   int64
#  1   sex       1338 non-null   object
#  2   bmi       1338 non-null   float64
#  3   children  1338 non-null   int64
#  4   smoker    1338 non-null   object
#  5   region    1338 non-null   object
#  6   charges   1338 non-null   float64
# dtypes: float64(2), int64(2), object(3)
# memory usage: 73.3+ KB

# %% [markdown]
# # ***Statistical summary***

# %%
data.describe()
# Out:
#                age          bmi     children       charges
# count  1338.000000  1338.000000  1338.000000   1338.000000
# mean     39.207025    30.663397     1.094918  13270.422265
# std      14.049960     6.098187     1.205493  12110.011237
# min      18.000000    15.960000     0.000000   1121.873900
# 25%      27.000000    26.296250     0.000000   4740.287150
# 50%      39.000000    30.400000     1.000000   9382.033000
# 75%      51.000000    34.693750     2.000000  16639.912515
# max      64.000000    53.130000     5.000000  63770.428010

# %%
# Summary statistics for categorical columns
categorical_columns = data.select_dtypes(include=['object']).columns
print("\nValue Counts for Categorical Columns:")
for col in categorical_columns:
    print(f"\nColumn: {col}")
    print(data[col].value_counts())
# Out:
# Value Counts for Categorical Columns:
#
# Column: sex
# sex
# male      676
# female    662
# Name: count, dtype: int64
#
# Column: smoker
# smoker
# no     1064
# yes     274
# Name: count, dtype: int64
#
# Column: region
# region
# southeast    364
# southwest    325
# northwest    325
# northeast    324
# Name: count, dtype: int64

# %% [markdown]
# # ***Check for messing data***

# %%
data.isnull().sum()
# Out:
# age         0
# sex         0
# bmi         0
# children    0
# smoker      0
# region      0
# charges     0
# dtype: int64

# %% [markdown]
# # ***Check duplicates***

# %%
data.duplicated().sum()
# Out:
# 0

# %% [markdown]
# # ***Handling duplicated values***

# %%
data = data.drop_duplicates()

# %%
data.duplicated().sum()
# Out:
# 0

# %% [markdown]
# # ***4. Exploratory Data Analysis (EDA)***

# %%
pip install summarytools
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: summarytools in c:\users\khalid\appdata\roaming\python\python312\site-packages (0.3.0)
# Requirement already satisfied: pandas>=1.4.0 in c:\program files\anaconda\lib\site-packages (from summarytools) (2.2.2)
# Requirement already satisfied: ipython>=7.20.0 in c:\users\khalid\appdata\roaming\python\python312\site-packages (from summarytools) (8.27.0)
# Requirement already satisfied: numpy>=1.18.5 in c:\program files\anaconda\lib\site-packages (from summarytools) (1.26.4)
# Requirement already satisfied: matplotlib>=3.3.0 in c:\program files\anaconda\lib\site-packages (from summarytools) (3.8.4)
# Requirement already satisfied: decorator in c:\users\khalid\appdata\roaming\python\python312\site-packages (from ipython>=7.20.0->summarytools) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in c:\users\khalid\appdata\roaming\python\python312\site-packages (from ipython>=7.20.0->summarytools) (0.19.1)
# Requirement already satisfied: matplotlib-inline in c:\users\khalid\appdata\roaming\python\python312\site-packages (from ipython>=7.20.0->summarytools) (0.1.7)
# Requirement already satisfied: prompt-toolkit<3.1.0,>=3.0.41 in c:\users\khalid\appdata\roaming\python\python312\site-packages (from ipython>=7.20.0->summarytools) (3.0.47)
# Requirement already satisfied: pygments>=2.4.0 in c:\users\khalid\appdata\roaming\python\python312\site-packages (from ipython>=7.20.0->summarytools) (2.18.0)
# Requirement already satisfied: stack-data in c:\users\khalid\appdata\roaming\python\python312\site-packages (from ipython>=7.20.0->summarytools) (0.6.3)
# Requirement already satisfied: traitlets>=5.13.0 in c:\users\khalid\appdata\roaming\python\python312\site-packages (from ipython>=7.20.0->summarytools) (5.14.3)
# Requirement already satisfied: colorama in c:\users\khalid\appdata\roaming\python\python312\site-packages (from ipython>=7.20.0->summarytools) (0.4.6)
# Requirement already satisfied: contourpy>=1.0.1 in c:\program files\anaconda\lib\site-packages (from matplotlib>=3.3.0->summarytools) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in c:\program files\anaconda\lib\site-packages (from matplotlib>=3.3.0->summarytools) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\program files\anaconda\lib\site-packages (from matplotlib>=3.3.0->summarytools) (4.51.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\program files\anaconda\lib\site-packages (from matplotlib>=3.3.0->summarytools) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\khalid\appdata\roaming\python\python312\site-packages (from matplotlib>=3.3.0->summarytools) (24.1)
# Requirement already satisfied: pillow>=8 in c:\program files\anaconda\lib\site-packages (from matplotlib>=3.3.0->summarytools) (10.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\program files\anaconda\lib\site-packages (from matplotlib>=3.3.0->summarytools) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\khalid\appdata\roaming\python\python312\site-packages (from matplotlib>=3.3.0->summarytools) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\program files\anaconda\lib\site-packages (from pandas>=1.4.0->summarytools) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\program files\anaconda\lib\site-packages (from pandas>=1.4.0->summarytools) (2023.3)
# Requirement already satisfied: parso<0.9.0,>=0.8.3 in c:\users\khalid\appdata\roaming\python\python312\site-packages (from jedi>=0.16->ipython>=7.20.0->summarytools) (0.8.4)
# Requirement already satisfied: wcwidth in c:\users\khalid\appdata\roaming\python\python312\site-packages (from prompt-toolkit<3.1.0,>=3.0.41->ipython>=7.20.0->summarytools) (0.2.13)
# Requirement already satisfied: six>=1.5 in c:\users\khalid\appdata\roaming\python\python312\site-packages (from python-dateutil>=2.7->matplotlib>=3.3.0->summarytools) (1.16.0)
# Requirement already satisfied: executing>=1.2.0 in c:\users\khalid\appdata\roaming\python\python312\site-packages (from stack-data->ipython>=7.20.0->summarytools) (2.1.0)
# Requirement already satisfied: asttokens>=2.1.0 in c:\users\khalid\appdata\roaming\python\python312\site-packages (from stack-data->ipython>=7.20.0->summarytools) (2.4.1)
# Requirement already satisfied: pure-eval in c:\users\khalid\appdata\roaming\python\python312\site-packages (from stack-data->ipython>=7.20.0->summarytools) (0.2.3)
# Note: you may need to restart the kernel to use updated packages.

# %%
from summarytools import dfSummary
dfSummary(data)
# Out:
# <style type="text/css">
# #T_5ef76 thead>tr>th {
#   text-align: left;
# }
# #T_5ef76_row0_col0, #T_5ef76_row1_col0, #T_5ef76_row2_col0, #T_5ef76_row3_col0, #T_5ef76_row4_col0, #T_5ef76_row5_col0, #T_5ef76_row6_col0 {
#   text-align: left;
#   font-size: 12px;
#   vertical-align: middle;
#   width: 5%;
#   max-width: 50px;
#   min-width: 20px;
# }
# #T_5ef76_row0_col1, #T_5ef76_row1_col1, #T_5ef76_row2_col1, #T_5ef76_row3_col1, #T_5ef76_row4_col1, #T_5ef76_row5_col1, #T_5ef76_row6_col1 {
#   text-align: left;
#   font-size: 12px;
#   vertical-align: middle;
#   width: 15%;
#   max-width: 200px;
#   min-width: 100px;
#   word-break: break-word;
# }
# #T_5ef76_row0_col2, #T_5ef76_row1_col2, #T_5ef76_row2_col2, #T_5ef76_row3_col2, #T_5ef76_row4_col2, #T_5ef76_row5_col2, #T_5ef76_row6_col2 {
#   text-align: left;
#   font-size: 12px;
#   vertical-align: middle;
#   width: 30%;
#   min-width: 100px;
# }
# #T_5ef76_row0_col3, #T_5ef76_row1_col3, #T_5ef76_row2_col3, #T_5ef76_row3_col3, #T_5ef76_row4_col3, #T_5ef76_row5_col3, #T_5ef76_row6_col3 {
#   text-align: left;
#   font-size: 12px;
#   vertical-align: middle;
#   width: 25%;
#   min-width: 100px;
# }
# #T_5ef76_row0_col4, #T_5ef76_row1_col4, #T_5ef76_row2_col4, #T_5ef76_row3_col4, #T_5ef76_row4_col4, #T_5ef76_row5_col4, #T_5ef76_row6_col4 {
#   text-align: left;
#   font-size: 12px;
#   vertical-align: middle;
#   width: 20%;
#   min-width: 150px;
# }
# #T_5ef76_row0_col5, #T_5ef76_row1_col5, #T_5ef76_row2_col5, #T_5ef76_row3_col5, #T_5ef76_row4_col5, #T_5ef76_row5_col5, #T_5ef76_row6_col5 {
#   text-align: left;
#   font-size: 12px;
#   vertical-align: middle;
#   width: 10%;
# }
# </style>
# <table id="T_5ef76">
#   <caption><strong>Data Frame Summary</strong><br>data<br>Dimensions: 1,337 x 7<br>Duplicates: 0</caption>
#   <thead>
#     <tr>
#       <th id="T_5ef76_level0_col0" class="col_heading level0 col0" >No</th>
#       <th id="T_5ef76_level0_col1" class="col_heading level0 col1" >Variable</th>
#       <th id="T_5ef76_level0_col2" class="col_heading level0 col2" >Stats / Values</th>
#       <th id="T_5ef76_level0_col3" class="col_heading level0 col3" >Freqs / (% of Valid)</th>
#       <th id="T_5ef76_level0_col4" class="col_heading level0 col4" >Graph</th>
#       <th id="T_5ef76_level0_col5" class="col_heading level0 col5" >Missing</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_5ef76_row0_col0" class="data row0 col0" >1</td>
#       <td id="T_5ef76_row0_col1" class="data row0 col1" ><strong>age</strong><br>[int64]</td>
#       <td id="T_5ef76_row0_col2" class="data row0 col2" >Mean (sd) : 39.2 (14.0)<br>min < med < max:<br>18.0 < 39.0 < 64.0<br>IQR (CV) : 24.0 (2.8)</td>
#       <td id="T_5ef76_row0_col3" class="data row0 col3" >47 distinct values</td>
#       <td id="T_5ef76_row0_col4" class="data row0 col4" ><img src = "......"></img></td>
#       <td id="T_5ef76_row0_col5" class="data row0 col5" >0<br>(0.0%)</td>
#     </tr>
#     <tr>
#       <td id="T_5ef76_row1_col0" class="data row1 col0" >2</td>
#       <td id="T_5ef76_row1_col1" class="data row1 col1" ><strong>sex</strong><br>[object]</td>
#       <td id="T_5ef76_row1_col2" class="data row1 col2" >1. male<br>2. female</td>
#       <td id="T_5ef76_row1_col3" class="data row1 col3" >675 (50.5%)<br>662 (49.5%)</td>
#       <td id="T_5ef76_row1_col4" class="data row1 col4" ><img src = "......"></img></td>
#       <td id="T_5ef76_row1_col5" class="data row1 col5" >0<br>(0.0%)</td>
#     </tr>
#     <tr>
#       <td id="T_5ef76_row2_col0" class="data row2 col0" >3</td>
#       <td id="T_5ef76_row2_col1" class="data row2 col1" ><strong>bmi</strong><br>[float64]</td>
#       <td id="T_5ef76_row2_col2" class="data row2 col2" >Mean (sd) : 30.7 (6.1)<br>min < med < max:<br>16.0 < 30.4 < 53.1<br>IQR (CV) : 8.4 (5.0)</td>
#       <td id="T_5ef76_row2_col3" class="data row2 col3" >548 distinct values</td>
#       <td id="T_5ef76_row2_col4" class="data row2 col4" ><img src = "......"></img></td>
#       <td id="T_5ef76_row2_col5" class="data row2 col5" >0<br>(0.0%)</td>
#     </tr>
#     <tr>
#       <td id="T_5ef76_row3_col0" class="data row3 col0" >4</td>
#       <td id="T_5ef76_row3_col1" class="data row3 col1" ><strong>children</strong><br>[int64]</td>
#       <td id="T_5ef76_row3_col2" class="data row3 col2" >Mean (sd) : 1.1 (1.2)<br>min < med < max:<br>0.0 < 1.0 < 5.0<br>IQR (CV) : 2.0 (0.9)</td>
#       <td id="T_5ef76_row3_col3" class="data row3 col3" >6 distinct values</td>
#       <td id="T_5ef76_row3_col4" class="data row3 col4" ><img src = "......"></img></td>
#       <td id="T_5ef76_row3_col5" class="data row3 col5" >0<br>(0.0%)</td>
#     </tr>
#     <tr>
#       <td id="T_5ef76_row4_col0" class="data row4 col0" >5</td>
#       <td id="T_5ef76_row4_col1" class="data row4 col1" ><strong>smoker</strong><br>[object]</td>
#       <td id="T_5ef76_row4_col2" class="data row4 col2" >1. no<br>2. yes</td>
#       <td id="T_5ef76_row4_col3" class="data row4 col3" >1,063 (79.5%)<br>274 (20.5%)</td>
#       <td id="T_5ef76_row4_col4" class="data row4 col4" ><img src = "......"></img></td>
#       <td id="T_5ef76_row4_col5" class="data row4 col5" >0<br>(0.0%)</td>
#     </tr>
#     <tr>
#       <td id="T_5ef76_row5_col0" class="data row5 col0" >6</td>
#       <td id="T_5ef76_row5_col1" class="data row5 col1" ><strong>region</strong><br>[object]</td>
#       <td id="T_5ef76_row5_col2" class="data row5 col2" >1. southeast<br>2. southwest<br>3. northwest<br>4. northeast</td>
#       <td id="T_5ef76_row5_col3" class="data row5 col3" >364 (27.2%)<br>325 (24.3%)<br>324 (24.2%)<br>324 (24.2%)</td>
#       <td id="T_5ef76_row5_col4" class="data row5 col4" ><img src = "......"></img></td>
#       <td id="T_5ef76_row5_col5" class="data row5 col5" >0<br>(0.0%)</td>
#     </tr>
#     <tr>
#       <td id="T_5ef76_row6_col0" class="data row6 col0" >7</td>
#       <td id="T_5ef76_row6_col1" class="data row6 col1" ><strong>charges</strong><br>[float64]</td>
#       <td id="T_5ef76_row6_col2" class="data row6 col2" >Mean (sd) : 13279.1 (12110.4)<br>min < med < max:<br>1121.9 < 9386.2 < 63770.4<br>IQR (CV) : 11911.4 (1.1)</td>
#       <td id="T_5ef76_row6_col3" class="data row6 col3" >1,337 distinct values</td>
#       <td id="T_5ef76_row6_col4" class="data row6 col4" ><img src = "......"></img></td>
#       <td id="T_5ef76_row6_col5" class="data row6 col5" >0<br>(0.0%)</td>
#     </tr>
#   </tbody>
# </table>

# %%
sns.set_theme(style="whitegrid", palette="pastel")
numerical_columns = data.select_dtypes(include=['float64', 'int64']).columns

plt.figure(figsize=(15, 15))

for i, col in enumerate(numerical_columns):
    plt.subplot(len(numerical_columns), 2, 2 * i + 1)
    sns.boxplot(data[col], orient='h', color="skyblue", linewidth=1.5)
    plt.title(f"Boxplot of {col}", fontsize=12, fontweight="bold")
    plt.xlabel(col, fontsize=10)

    plt.subplot(len(numerical_columns), 2, 2 * i + 2)
    sns.histplot(data[col], kde=True, color="brown", linewidth=1)
    plt.title(f"Distribution Plot of {col}", fontsize=12, fontweight="bold")
    plt.xlabel(col, fontsize=10)
    plt.ylabel("Density", fontsize=10)

plt.tight_layout()
plt.show()

# %%
sns.set_theme(style="whitegrid", palette="pastel")
categorical_columns = data.select_dtypes(include=['object']).columns

plt.figure(figsize=(15, 8))  

for i, col in enumerate(categorical_columns):
    plt.subplot(1, len(categorical_columns), i + 1)
    sns.countplot(x=col, data=data, palette='Set2',hue='smoker')
    plt.title(f"Count Plot of {col}", fontsize=14, fontweight="bold")
    plt.xlabel(col, fontsize=12)
    plt.ylabel("Count", fontsize=12)
    plt.xticks(rotation=45)

plt.tight_layout()
plt.show()

# %%
X = list(data.bmi)
Y = list(data.charges)
X = np.array(X).reshape(-1,1)
Y = np.array(Y).reshape(-1,1)

# %%
X_train,X_test,Y_train,Y_test = train_test_split(X,Y,test_size=0.2,random_state=42)

# %%
model = LinearRegression()
model.fit(X_train,Y_train)
# Out:
# LinearRegression()

# %%
Y_predict = model.predict(X_test)

# %%
print("Intercept:", model.intercept_[0])
print("Coefficient:", model.coef_[0][0])
# Out:
# Intercept: 1353.0730722046683
# Coefficient: 392.43654416987977

# %%
mse = mean_squared_error(Y_test, Y_predict)
print("Mean Squared Error:", mse)
# Out:
# Mean Squared Error: 149085057.03839505

# %%
plt.scatter(X_test,Y_test,color="green",label="actual")
plt.plot(X_test,Y_predict,color="red",label="Predicted")
plt.xlabel("age")
plt.ylabel("bmi")
plt.title("Linear regression")
plt.legend()
plt.show()

# %%
data.loc[1300,["bmi","charges"]]
# Out:
# bmi              30.36
# charges    62592.87309
# Name: 1300, dtype: object

# %%
model.predict([[30.36]])
# Out:
# array([[13267.4465532]])

# %%
from math import sqrt
def mean(arr):
    return sum(arr)/len(arr)

def variance(arr):
    m = mean(arr)
    s = 0
    for i in arr:
        s = s +pow((i-m),2)
    return s/(len(arr)-1)

def standard_deviation(arr):
    return sqrt(variance(arr))
    
def covariance(X,Y) :
    mX = mean(X)
    mY = mean(Y)
    cov = 0
    N = len(X)
    for x,y in zip(X,Y):
        cov = cov + ((x-mX)*(y-mY))
    return cov/N

def correlation(X,Y) :
    dev_X = standard_deviation(X)
    dev_Y = standard_deviation(Y)
    cov = covariance(X,Y)
    return cov/(dev_X*dev_Y)

# %%
Xcor = list(data.bmi)
Ycor = list(data.charges)
print(correlation(X,Y))
# Out:
# [0.19819273]
# C:\Users\KHALID\AppData\Local\Temp\ipykernel_3904\1402327514.py:13: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   return sqrt(variance(arr))
